# %% [markdown]
# # <center>CHIRAC ou MITTERAND ? </center>

# %%
#Bibliothèques utiles
import numpy as np
import matplotlib.pyplot as plt
import codecs
import re
import os.path

# %% [markdown]
# ## Chargement des données

# %%
# Chargement des données:
def load_pres(fname):
    alltxts = []
    alllabs = []
    s=codecs.open(fname, 'r','utf-8') # pour régler le codage
    while True:
        txt = s.readline()
        if(len(txt))<5:
            break
        #
        lab = re.sub(r"<[0-9]*:[0-9]*:(.)>.*","\\1",txt) #recupère le label (C ou M)
        txt = re.sub(r"<[0-9]*:[0-9]*:.>(.*)","\\1",txt) #recupère le texte
        if lab.count('M') >0:
            alllabs.append(-1)
        else:
            alllabs.append(1) #si c'est Mitterand qui parle on met -1 si c'est Chirac, on met 1
        alltxts.append(txt)
    return alltxts,alllabs

fname = "./corpus.tache1.learn.utf8"
alltxts,alllabs = load_pres(fname)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 21
#      18     return alltxts,alllabs
#      20 fname = "./corpus.tache1.learn.utf8"
# ---> 21 alltxts,alllabs = load_pres(fname)
#
# Cell In[1], line 5, in load_pres(fname)
#       3 alltxts = []
#       4 alllabs = []
# ----> 5 s=codecs.open(fname, 'r','utf-8') # pour régler le codage
#       6 while True:
#       7     txt = s.readline()
#
# NameError: name 'codecs' is not defined
